# %% [markdown]
# <a href="https://colab.research.google.com/github/syafikhakim25-pixel/DasarPPLG-X-2627/blob/main/X_PPLG_SyafiqHakim_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 Praktik membuat tipe data dan variabel
# Nama kelompok: iq + ketenangan
# nama anggota :
# 1.Syafiq hakim
# 2.Rafa Anurwansyah
# 3.Habibi Hamka
# 4.Satria Aprilliansyah
# 5.fiqih Ramadhan

# %%
# %%writefile praktik_variabel.cpp
# #include<iostream>
# #include<string>
# using namespace std;
#
# int main() {
#  // Deklarasi Variabel dan Tipe Data
# string namaBarang = "iPhone Kupih";
# int jumlah =2;
# float harga =75000000.50;
# char kategori = 'A';
# bool tersedia= true;
#
# //Menampilkan Output Ke Layar
# cout << "==DATA INVESTASIS=="<< endl;
# cout << "iPhone Kupih :"<< namaBarang <<endl;
# cout << "kategori     :"<<kategori <<endl;
# cout << "jumlah       :"<<jumlah <<endl;
# cout << "75000000.50  :"<<harga <<endl;
# cout << "tersedia     :"<<tersedia <<"(1 = Ya, 0 = Tidak)"<<endl;
# cout << "===================="<<endl;
#
# return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# ==DATA INVESTASIS==
# iPhone Kupih :iPhone Kupih
# kategori     :A
# jumlah       :2
# 75000000.50  :7.5e+07
# tersedia     :1(1 = Ya, 0 = Tidak)
# ...
